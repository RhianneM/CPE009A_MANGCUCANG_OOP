# %% [markdown]
# <a href="https://colab.research.google.com/github/RhianneM/CPE009A_MANGCUCANG_OOP/blob/main/Laboratory_Activity_1_Literals%2C_Operators%2C_and_Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Assigning variables of different data types in Python **

# %%
value = 5
print (value)
# Out:
# 5

# %%
type (value)
# Out:
# int

# %%
value = 5.0
print (value)
# Out:
# 5.0
# float

# %%
type (value)
# Out:
# float

# %%
#a.
value = 2 + 3j
print (value)
type (value)
# Out:
# (2+3j)
# complex

# %%
#b.
value = 'Hello World'
print (value)
type (value)
# Out:
# Hello World
# str

# %%
#c.
value = "Hello World"
print (value)
type (value)
# Out:
# Hello World
# str

# %%
#d.
value = True
print (value)
type (value)
# Out:
# True
# bool

# %%
#e
value = False
print (value)
type (value)
# Out:
# False
# bool

# %%
#f
value = [1,2,3,4,5]
print (value)
type (value)
# Out:
# [1, 2, 3, 4, 5]
# list

# %%
#g
value =  (1,2,3,4,5)
print (value)
type (value)
# Out:
# (1, 2, 3, 4, 5)
# tuple

# %%
#h
value = { 'name': 'Rhianne'}
print (value)
type (value)
# Out:
# {'name': 'Rhianne'}
# dict

# %%
#i
value = None
print (value)
type (value)
# Out:
# None
# NoneType

# %% [markdown]
# # **Performing Operations with Python**

# %%
value = 5
value2 = -6
print (value + value2)
# Out:
# -1

# %%
#a
value, value2 = 5.0, 6
print (value + value2)
# Out:
# 11.0

# %%
#b
value, value2 = -5, 6.1
print (value + value2)
# Out:
# 1.0999999999999996

# %%
#c
value, value2 = "Hello" , ' world'
print (value + value2)
# Out:
# Hello world

# %%
#d
value, value2 = [1,2,3], [4,5,6]
print (value + value2)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#e
value, value2 = (1,2,3), (4,5,6)
print (value + value2)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
#f
value, value2 = {"name" : "Royce"}, {"age" : 2}
print (value , value2)
# Out:
# {'name': 'Royce'} {'age': 2}

# %%
value, value2 = 30,4

# %%
#a
print (value * value2)
# Out:
# 120

# %%
#b
print (value ** 2)
# Out:
# 900

# %%
#c
print (value ** 3)
# Out:
# 27000

# %%
#d
print (value * value2 + value2 ** 2 + 1)
# Out:
# 137

# %%
#e
print (value / value2)
# Out:
# 7.5

# %%
#f
print (value % value2)
# Out:
# 2

# %% [markdown]
# # Receiving Input Data using Python

# %%
name = input ("Enter your name:")
weight = float(input ("Enter your weight (kg): "))
height = float(input ("Enter your height (m): "))
bmi = weight / (height *  height)


print ("\nname:", name)
print ("weight:", weight)
print ("height:", height)
print ("bmi:", bmi)

# %% [markdown]
# # **SUPPLEMENTARY TASK**

# %%
#1. Write the Python equivalent code of the following C code:
base = float(input("Enter the base of the triangle: "))
height = float(input("Enter the height of the triangle: "))

area = 0.5 * base * height
print ("The area of the triangle is:", area)
# Out:
# Enter the base of the triangle: 12
# Enter the height of the triangle: 32
# The area of the triangle is: 192.0

# %%
#2. Write a program that would convert Celsius to Fahrenheit given the formula: F= (C x 9/5) + 32
C = float(input("Enter the temperature in Celsius: "))
F = (C * 9/5) + 32
print ("The temperature in Fahrenheit is:", F)
# Out:
# Enter the temperature in Celsius: 124
# The temperature in Fahrenheit is: 255.2

# %%
#3 Write a program that can determine the distance between two points given the coordinates using the formula d = √(x2 - x1)**2 + (y2 - y1)**2
x1, y1 = float(input("Enter the x-coordinate of the first point: ")), float(input("Enter the y-coordinate of the first point: "))
x2, y2 = float(input("Enter the x-coordinate of the second point: ")), float(input("Enter the y-coordinate of the second point: "))

d = ((x2 - x1)**2 + (y2 - y1)**2) ** 0.5
print (d)
# Out:
# Enter the x-coordinate of the first point: 2
# Enter the y-coordinate of the first point: 2
# Enter the x-coordinate of the second point: -3
# Enter the y-coordinate of the second point: 3
# 5.0990195135927845
