# %% [markdown]
# <a href="https://colab.research.google.com/github/RhianneM/CPE009A_MANGCUCANG_OOP/blob/main/MIDTERM_EXAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Q23
# #Write a program that uses nested loops to print this pattern:
#
# *#
#
# **#
#
# ***#
#
# ****#
#
# *****#
#
# ****#
#
# ***#
#
# **#
#
# *#

# %%
def num():
  def star():
    number = (int(input("Enter how many astersisk?:")))
    number = (1,2,3,4,5)
    print (number)


x=1
while x<=5:
  print ("*"*x)
  x+=1
if x<=1:
  print ("*")
if x<2:
   print ("**")
if x<= 3:
    print ("****")
if x<= 4:
    print ("****")
if x<=5:
    print ("*****")
if x>1:
  print ("****")
  print ("***")
  print ("**")
  print ("*")
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %% [markdown]
# ##Q24
#
# Write a function that checks if a string of parentheses (), brackets [], and braces {} is balanced.
#
# Examples:
#
#     "({[]})" → True
#
#     "([)]" → False
#
#     "((()))" → True
#
#     "({)}" → False

# %%
elem=(int(input("Enter element:")))
print (elem)
element = (), {}, []

if element == ():
  print ("true")
else:
  print ("False")
