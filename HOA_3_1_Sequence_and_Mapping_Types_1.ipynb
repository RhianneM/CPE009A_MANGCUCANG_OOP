# %% [markdown]
# <a href="https://colab.research.google.com/github/RhianneM/CPE009A_MANGCUCANG_OOP/blob/main/HOA_3_1_Sequence_and_Mapping_Types_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HOA#3.1 - Prelim

# %% [markdown]
# Name: Mangcucang, Rhianne L.
#
# Section: CPE12S2
#
# Date performed: 02/26/26

# %% [markdown]
# 1\. Make a program that takes two input and identifies if the first number is divisible by the second number.

# %% [markdown]
# 2\. Task 2

# %% [markdown]
# ## Contents
#  - [Procedures](#procedures)
#  - [Supplementary Activity](#supplementary_activities)
#  - [Conclusion](#conclusion)

# %% [markdown]
# ## Instructions for Lab Activities
# ---
# Document all procedures and supplementary tasks performed in the activity.
#
# You may use these links for reference on markdown with Jupyter:
#
# https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Notebook%20Basics.html
#
# https://colab.research.google.com/notebooks/welcome.ipynb
#
# https://colab.research.google.com/notebooks/markdown_guide.ipynb
#
# Be creative in documenting how you did the procedures below using the markdown. Also provide your observations as often as necessary per step.
#
# Place your code per **In [ ]** corresponding to the specified procedure. An example is given below

# %% [markdown]
# ## <a id="procedures">Procedures</a>

# %% [markdown]
# ##List

# %%
numberlist = [5, 4, 3, 2 ,1]

# %%
len(numberlist)
# Out:
# 5

# %%
numberlist[0]
# Out:
# 5

# %%
numberlist[1]
# Out:
# 4

# %%
numberlist[2]
# Out:
# 3

# %%
numberlist[3]
# Out:
# 2

# %%
numberlist[4]
# Out:
# 1

# %%
numberlist[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-639/645683220.py in <cell line: 0>()
# ----> 1 numberlist[5]
#
# IndexError: list index out of range

# %%
numberlist[-1]
# Out:
# 1

# %%
numberlist[-2]
# Out:
# 2

# %%
numberlist[-3]
# Out:
# 3

# %%
numberlist[-4]
# Out:
# 4

# %%
numberlist[-5]
# Out:
# 5

# %%
numberlist[-6]

# %% [markdown]
# ##Observation:
#
# * Index starts at 0
# * Accessing beyond range gives IndexError
# * Negative index starts -1

# %%
itemlist= [1,-2.0,[1,2,3],"Word"]

# %%
len(itemlist)
# Out:
# 4

# %%
itemlist [0]
# Out:
# 1

# %%
itemlist [1]
# Out:
# -2.0

# %%
itemlist [2]
# Out:
# [1, 2, 3]

# %%
itemlist [3]
# Out:
# 'Word'

# %%
len(itemlist[2])
# Out:
# 3

# %%
itemlist [2][0]
# Out:
# 1

# %%
itemlist [2][1]
# Out:
# 2

# %%
itemlist [2][2]
# Out:
# 3

# %%
itemlist [-1]
# Out:
# 'Word'

# %%
itemlist [-1]
# Out:
# 'Word'

# %%
itemlist [-2]
# Out:
# [1, 2, 3]

# %%
itemlist [-3]
# Out:
# -2.0

# %%
itemlist [-4]
# Out:
# 1

# %%
len(itemlist[-2])
# Out:
# 3

# %%
itemlist [-2][0]
# Out:
# 1

# %%
itemlist [-2][1]
# Out:
# 2

# %%
itemlist [-2][2]
# Out:
# 3

# %%
itemlist [-2][-3]
# Out:
# 1

# %%
itemlist [-2][-2]
# Out:
# 2

# %%
itemlist [-2][-1]
# Out:
# 3

# %% [markdown]
# ##Observation:
# * List contains different types
# * Nested list uses double indexing

# %% [markdown]
# ##Index Slicing

# %%
itemlist= [1,-2.0,[1,2,3],"Word"]
numberlist = [5, 4, 3, 2 ,1]

longlist = numberlist + itemlist
print (longlist)
# Out:
# [5, 4, 3, 2, 1, 1, -2.0, [1, 2, 3], 'Word']

# %%
len(longlist)
# Out:
# 9

# %%
longlist [:]
# Out:
# [5, 4, 3, 2, 1, 1, -2.0, [1, 2, 3], 'Word']

# %%
longlist [:9]
# Out:
# [5, 4, 3, 2, 1, 1, -2.0, [1, 2, 3], 'Word']

# %%
longlist [0:]
# Out:
# [5, 4, 3, 2, 1, 1, -2.0, [1, 2, 3], 'Word']

# %%
longlist [1:]
# Out:
# [4, 3, 2, 1, 1, -2.0, [1, 2, 3], 'Word']

# %%
longlist [2:]
# Out:
# [3, 2, 1, 1, -2.0, [1, 2, 3], 'Word']

# %% [markdown]
# ##Index Slicing with Range

# %%
longlist [2:5]
# Out:
# [3, 2, 1]

# %%
longlist [5:2]
# Out:
# []

# %%
longlist [8:]
# Out:
# ['Word']

# %%
longlist [9:]

# %% [markdown]
# ##Index Slicing using Negative Indices

# %%
longlist [-9:]
# Out:
# [5, 4, 3, 2, 1, 1, -2.0, [1, 2, 3], 'Word']

# %%
longlist [-8:]
# Out:
# [4, 3, 2, 1, 1, -2.0, [1, 2, 3], 'Word']

# %%
longlist[-8:-7]
# Out:
# [4]

# %%
longlist [-1:]
# Out:
# ['Word']

# %% [markdown]
# ##Other Properties of Index Slicing

# %%
longlist [10:20]
# Out:
# []

# %%
longlist [-7:5]
# Out:
# [3, 2, 1]

# %% [markdown]
# ##Index Slicing with Step Parameter

# %%
longlist [::1]
# Out:
# [5, 4, 3, 2, 1, 1, -2.0, [1, 2, 3], 'Word']

# %%
longlist [::2]
# Out:
# [5, 3, 1, -2.0, 'Word']

# %%
longlist [1:8:2]
# Out:
# [4, 2, 1, [1, 2, 3]]

# %%
longlist [9:1:-1]
# Out:
# ['Word', [1, 2, 3], -2.0, 1, 1, 2, 3]

# %%
longlist [-1::1]
# Out:
# ['Word']

# %%
longlist [-1::-1]
# Out:
# ['Word', [1, 2, 3], -2.0, 1, 1, 2, 3, 4, 5]

# %% [markdown]
# ##Observation
# *
# *

# %% [markdown]
# ## <a id="supplementary_activities">Supplementary Activity</a>

# %% [markdown]
# ## <a id="conclusion">Conclusion</a>
